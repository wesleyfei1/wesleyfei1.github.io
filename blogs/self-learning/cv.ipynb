# %%
CG05
1.插值：输入为一些数据点，输出为一系列的反映数据规律的函数
逼近：需要找到f，有min(yi-f(xi))^2，最小二乘
从而使用一组的完备的函数系
lagrange插值函数（n+1个方程以及n+1个变量）
2.过拟合以及处理方法
标注数据集，
深度学习
CG06 2D图形的光栅化
即为如何讲一个2D图形给变成一个可以再光栅显示器上面显示的格式
1.线段的实现：两种算法DDA(每一个x画出最接近的整数y)，Bresenham算法：使用决策变量，计算上下的距离之差从而得到是使用上还是下像素
2.对于多边形的实现：
内与外：若射线与边界的交点数为奇数，内
结构：扫描线，类似与双重链表的结构
3.光滑曲线：f(xi,yi)>0 or <0->对应着向那个方向走

4.走样现象：
引入中间颜色
数学本质：使用低通滤波去除高频信息

CG07
插值，逼近
使用函数空间，而对于loss f,we use data term,regularizatio来限制
优化为grad declining and so on 
2.采样方法：
1D曲线：分段线性逼近，2D曲线的采样方法；
GMM模型方法
超限采样：拟合对于其余属性的东西，比如导数，曲率，内积（Chebyshev,Legend逼近）
边界的拟合：
1D,曲线

CG08
高阶PDE
1.Poisson Image Editing:
通过变换将原本的图像变成I,然后变成div之后的东西，最后把图抠出来
可以保证其边界类似于泊松方程一样可以有合适的纹理


CG 09
采样，计算数学
PDE的数值解以及精度，高效
数值解的原理：将partial->差分的形式
1.sampling therom:x(t) with B hertz requires no more than 2B samples per second
2.平面分割重的三角分割
德劳内三角剖分，采样点，voronoi图以及别的方法
something else

CG 10
三维曲面表示，使用多面体，嵌入，网格数据存储
网格数据结构：存储的若干种方式
CG 11
全局坐标
laplace 坐标(差分坐标)：one-ring neighbor+delta  and it is differentiall coordinate
(the problem is it can't represent 曲率)
laplace 矩阵
reconstruction将laplace坐标变成全局坐标
极小曲面：平均曲率处处为0的曲面

CG 12
曲面参数化：
ARAP参数化方法(area),asap(angle),混合参数

CG 13
2D,3D下的切线与曲率，均值与开根号=》离散微分集合

CG 15
reconstruction将laplace坐标变成全局坐标
直接沟网法，mesh smoothing,denoising

CG 16
1.渲染：将实际的内容输出到显示设备的过程
自然界种为通过眼睛或者相机变成二维的东西（投影，采集=>采样）
3D->2D：几何变换(计算位置，光栅化，将集合图像转换成像素)+着色
2.对于局部着色模型：(1)对于顶点的着色是通过周围的法向平均得到的，漫反射，背景光，镜面反射
环境光：模拟多次反射之后的效果，高光系数

对于非顶点的东西：三个顶点插值

3.由于光栅着色方法是局部光照，无法生成阴影
中心思想：光源+眼睛，soft shadow,depth(分辨率)，浮点比较
同时还有别的渲染途径


OpenGL教学，生成一堆的图形

GPU:矩阵乘法，并行计算，CUDA
Lo=Le+S(Lifr cos theta)dl

全局渲染(BRDF，光路不断传播，辐射律)虽然但是我们需要跟踪光纤

只有到达视点的光线=》逆着方向投射光纤，each pixel need at least one ray


相交的时候有的会被吸收，而对于无穷空间的光线(递归的步数有限制)。

折射光纤+反射+other，而对于光线传播的时候注意有无intersect
Phone model

对于光线的积分如何求解？随机采样一条，多次计算(从视点打出n条，每个电按照概率产生一个，取平均)

monte Carlo积分方法(随机采样方法)，辐射度方法(一个奇特的假设，全部为漫发射)


纹理映射，时时映射



计算机动画
关键正插值非常重要
(1)时间的离散，物理仿真(tn->tn+1)
euler,half-euler,zero-euler

2.弹性体仿真，碰撞处理，流体仿真，粒子仿真，角色动画，刚体动力学
3.不同的视图，
